# %%
# %pylab inline
import matplotlib.pyplot as plt
import numpy as np
from numpy import pi
from mpl_toolkits.mplot3d import Axes3D
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
image = pylab.imread('colesterol-1.tif')
fig = figure(1, figsize=(6.5,4.5))
imshow(image[:,:], cmap = cm.Greys_r)
plt.title('Imagen Original', fontsize=12)
print shape(image)
# Out:
# (244, 357)

# %%
from scipy import fftpack
img_ft = fftpack.fft2(image, axes=(0, 1))
print len(img_ft[0,:]), len(img_ft[:,0])
# Out:
# 357 244

# %%
fig = figure(1, figsize=(6.5,4.5))
ax=fig.add_subplot(111,projection='3d')
#xedges, yedges=histogram2d(img_ft[:,0],img_ft[0,:],bins=4)
elements=(len(img_ft[:,0])-1,len(img_ft[0,:])-1)
xpos, ypos=meshgrid(img_ft[:,0],img_ft[0,:])
xpos=xpos.flatten()
ypos=ypos.flatten()
dx=0.5*ones_like(zpos)
dy=dx.copy()
dz=hist.flatten()
ax.bar3d(xpos, ypos, zpos, dx, dy, dz, coor='b', zsort='average')
show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-ccb032e923db> in <module>()
#       6 xpos=xpos.flatten()
#       7 ypos=ypos.flatten()
# ----> 8 dx=0.5*ones_like(zpos)
#       9 dy=dx.copy()
#      10 dz=hist.flatten()
#
# NameError: name 'zpos' is not defined

# %%
X=[]
Y=[]
Z=[]
for i in range(0,len(img_ft[:,0])):
    Y.append(i)
for i in range(0,len(img_ft[0,:])):
    X.append(i)
def ft(x,y):
    return img_ft[x,y]
#fig=figure(figsize=(10,10))
#ax=fig.add_subplot(1,1,1,projection='3d')
#p=ax.plot_wireframe(X,Y,ft(X,Y),rstride=4, cstride=4)
plot(Y,ft(243,Y))

# %%
print len(X), len(Y), img_ft[0,0]
# Out:
# 357 244 (13646223+0j)

# %%
romp=[]
for i in range(0,len(img_ft[:,0])):
# Out:
#   File "<ipython-input-7-0f600dd384dc>", line 3
#
#     ^
# IndentationError: expected an indented block

# %%
#Creamos las fichas del rompecabezas, y la del rompecabezas armado.
romp=[]
A=[]
B=[]
C=[]
D=[]
for i in range(0,len(img_ft[:,0])):
    romp.append([])
for i in range(0,len(Y)/2):
    A.append([])
    B.append([])
    C.append([])
    D.append([])

#Este es el método que separa los cuadrantes de la imagen, para que un método próximo se arme.
def inicio():
    for i in range(0,len(Y)/2):
        for j in range(0,(len(X)-1)/2):
            A[i].append(img_ft[i,j])
            B[i].append(img_ft[i,j+((len(X)-1)/2)])
            C[i].append(img_ft[i+(len(Y)/2),j])
            D[i].append(img_ft[i+(len(Y)/2),j+((len(X)-1)/2)])

# %%
inicio()

# %%
print D[100][150]
print img_ft[3,3]
# Out:
# (176.573966544+4922.58674259j)
# (-23576.768265-70291.1534094j)
